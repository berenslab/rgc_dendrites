# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import h5py

# %%
label_fontsize = 22
tick_fontsize = 18
cbar_fontsize = 16

cmap = plt.cm.jet
vmin=-1
vmax=1

# %% [markdown]
# # Threshold 40

# %% [markdown]
# ## lchirp

# %%
filepath = './data/processed/lchirp_corr_40.csv'

df = pd.read_csv(filepath, index_col=0)

# %% [markdown]
# ### toffa

# %%
toffa = df[df.type == 0]
x = toffa['lChirpCorr_distance'].values
y = toffa['lChirpCorr_Angle'].values
z = toffa['lChirp_corr'].values

xlim_fixed = 600
ylim_fixed = 200

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8,  vmin=vmin, vmax=vmax, cmap=cmap)

# cb = fig.colorbar(im1, ax=ax, drawedges=False)
# cb.set_label("Overlap Index", fontsize=cbar_fontsize*0.8)
# cb.outline.set_visible(False)
# cb.solids.set_edgecolor("face")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### soff

# %%
soffa = df[df.type == 1]
x = soffa['lChirpCorr_distance'].values
y = soffa['lChirpCorr_Angle'].values
z = soffa['lChirp_corr'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8,  vmin=vmin, vmax=vmax, cmap=cmap)

# cb = fig.colorbar(im1, ax=ax, drawedges=False)
# cb.set_label("Overlap Index", fontsize=cbar_fontsize*0.8)
# cb.outline.set_visible(False)
# cb.solids.set_edgecolor("face")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### minia

# %%
off_mini = df[df.type == 2]
x = off_mini['lChirpCorr_distance'].values
y = off_mini['lChirpCorr_Angle'].values
z = off_mini['lChirp_corr'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8,  vmin=vmin, vmax=vmax, cmap=cmap)

# cb = fig.colorbar(im1, ax=ax, drawedges=False)
# cb.set_label("Overlap Index", fontsize=cbar_fontsize*0.8)
# cb.outline.set_visible(False)
# cb.solids.set_edgecolor("face")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ## chirp

# %%
filepath = './data/processed/chirp_corr_40.csv'

df = pd.read_csv(filepath, index_col=0)

# %% [markdown]
# ### toffa

# %%
toffa = df[df.type == 0]
x = toffa['ChirpCorr_distance'].values
y = toffa['ChirpCorr_Angle'].values
z = toffa['Chirp_corr'].values

# xlim_fixed = int(np.ceil(x.max() / 100.0)) * 100
# ylim_fixed = int(np.ceil(y.max() / 100.0)) * 100

xlim_fixed = 600
ylim_fixed = 200

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax, cmap=cmap)

# cb = fig.colorbar(im1, ax=ax, drawedges=False)
# cb.set_label("Overlap Index", fontsize=cbar_fontsize*0.8)
# cb.outline.set_visible(False)
# cb.solids.set_edgecolor("face")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### soff

# %%
soffa = df[df.type == 1]
x = soffa['ChirpCorr_distance'].values
y = soffa['ChirpCorr_Angle'].values
z = soffa['Chirp_corr'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax, cmap=cmap)

# cb = fig.colorbar(im1, ax=ax, drawedges=False)
# cb.set_label("Overlap Index", fontsize=cbar_fontsize*0.8)
# cb.outline.set_visible(False)
# cb.solids.set_edgecolor("face")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### mini-alpha

# %%
off_mini = df[df.type == 2]
x = off_mini['ChirpCorr_distance'].values
y = off_mini['ChirpCorr_Angle'].values
z = off_mini['Chirp_corr'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax, cmap=cmap)

# cb = fig.colorbar(im1, ax=ax, drawedges=False)
# cb.set_label("Overlap Index", fontsize=cbar_fontsize*0.8)
# cb.outline.set_visible(False)
# cb.solids.set_edgecolor("face")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# # Threshold 50

# %% [markdown]
# ## lchrip

# %%
filepath = './data/processed/lchirp_corr_50.csv'

df = pd.read_csv(filepath, index_col=0)

# %% [markdown]
# ### toffa

# %%
toffa = df[df.type == 0]
x = toffa['lChirpCorr_distance'].values
y = toffa['lChirpCorr_Angle'].values
z = toffa['lChirp_corr'].values

xlim_fixed = 600
ylim_fixed = 200

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8,  vmin=vmin, vmax=vmax, cmap=cmap)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### soff

# %%
soffa = df[df.type == 1]
x = soffa['lChirpCorr_distance'].values
y = soffa['lChirpCorr_Angle'].values
z = soffa['lChirp_corr'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8,  vmin=vmin, vmax=vmax, cmap=cmap)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### mini-alpha

# %%
off_mini = df[df.type == 2]
x = off_mini['lChirpCorr_distance'].values
y = off_mini['lChirpCorr_Angle'].values
z = off_mini['lChirp_corr'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8,  vmin=vmin, vmax=vmax, cmap=cmap)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ## chirp

# %%
filepath = './data/processed/chirp_corr_50.csv'

df = pd.read_csv(filepath, index_col=0)

# %% [markdown]
# ### toffa

# %%
toffa = df[df.type == 0]
x = toffa['ChirpCorr_distance'].values
y = toffa['ChirpCorr_Angle'].values
z = toffa['Chirp_corr'].values

# xlim_fixed = int(np.ceil(x.max() / 100.0)) * 100
# ylim_fixed = int(np.ceil(y.max() / 100.0)) * 100

xlim_fixed = 600
ylim_fixed = 200

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax, cmap=cmap)

# cb = fig.colorbar(im1, ax=ax, drawedges=False)
# cb.set_label("Overlap Index", fontsize=cbar_fontsize*0.8)
# cb.outline.set_visible(False)
# cb.solids.set_edgecolor("face")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### soff

# %%
soffa = df[df.type == 1]
x = soffa['ChirpCorr_distance'].values
y = soffa['ChirpCorr_Angle'].values
z = soffa['Chirp_corr'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax, cmap=cmap)

# cb = fig.colorbar(im1, ax=ax, drawedges=False)
# cb.set_label("Overlap Index", fontsize=cbar_fontsize*0.8)
# cb.outline.set_visible(False)
# cb.solids.set_edgecolor("face")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### mini-alpha

# %%
off_mini = df[df.type == 2]
x = off_mini['ChirpCorr_distance'].values
y = off_mini['ChirpCorr_Angle'].values
z = off_mini['Chirp_corr'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))
im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax, cmap=cmap)

# cb = fig.colorbar(im1, ax=ax, drawedges=False)
# cb.set_label("Overlap Index", fontsize=cbar_fontsize*0.8)
# cb.outline.set_visible(False)
# cb.solids.set_edgecolor("face")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)
