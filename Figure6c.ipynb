# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('./data/processed/current_injection.csv', delimiter=',', index_col=0)

# %%
g = sns.lmplot(x='SomaticSpikes', y='DendriticCalcium_area',col='group', data=df,
              x_ci='ci', ci=95, scatter_kws={'color': 'black'}, line_kws={'color': 'black'})
plt.ylim(0, 180)
plt.xlim(0, 60)
# Out:
# (0, 60)

# %% [markdown]
# group 0 = tOff alpha Proximal
#
# group 1 = tOff alpha Distal
#
# group 2 = tOff mini Proximal
#
# group 3 = tOff mini Distal
