# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

filepath = './data/processed/overlap.csv'

label_fontsize = 22
tick_fontsize = 18
cbar_fontsize = 16

df = pd.read_csv(filepath, index_col=0)

vmin = 0
vmax = 1

# %% [markdown]
# # tOffa

# %%
toffa = df[df.type == 0]
x = toffa['dendritic_distance_between_rois'].values
y = toffa['cbpt_angle_between_rois_deg'].values
z = toffa['overlap_index'].values

xlim_fixed = int(np.ceil(x.max() / 100.0)) * 100
ylim_fixed = int(np.ceil(y.max() / 100.0)) * 100

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))

im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# fig.savefig('figs/fig_4c_tOff_alpha.pdf')

# %% [markdown]
# # sOff

# %%
soff = df[df.type == 1]
x = soff['dendritic_distance_between_rois'].values
y = soff['cbpt_angle_between_rois_deg'].values
z = soff['overlap_index'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))


im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# fig.savefig('figs/fig_4c_sOff.pdf')

# %% [markdown]
# # mini-alpha

# %%
off_mini = df[df.type == 2]
x = off_mini['dendritic_distance_between_rois'].values
y = off_mini['cbpt_angle_between_rois_deg'].values
z = off_mini['overlap_index'].values

ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))


im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# fig.savefig('figs/fig_4c_tOff_mini.pdf')

# %% [markdown]
# # f-mini

# %%
f_mini = df[df.type == 3]
x = f_mini['dendritic_distance_between_rois'].values
y = f_mini['cbpt_angle_between_rois_deg'].values
z = f_mini['overlap_index'].values


ratiox = round(16 * x.max() / xlim_fixed).astype(int)
ratioy = round(10 * y.max() / ylim_fixed).astype(int)
gSize=[ratiox, ratioy]

fig, ax = plt.subplots(1,1, figsize=(8,8))

im1 = ax.hexbin(x, y, C=z, gridsize=gSize, alpha=0.8, vmin=vmin, vmax=vmax)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.tick_params(labelsize=tick_fontsize, width=2)

ax.set_xlabel('Dendritic distance between ROIs', fontsize=label_fontsize*0.8)
ax.set_ylabel('Angle between ROIs', fontsize=label_fontsize*0.8)

ax.set_xlim(-30,xlim_fixed)
ax.set_ylim(-10,ylim_fixed)
sns.despine(offset=10, trim=True)

# fig.savefig('figs/fig_4c_f_mini.pdf')
